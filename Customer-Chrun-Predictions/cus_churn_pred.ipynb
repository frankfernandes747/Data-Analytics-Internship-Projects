# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, classification_report

# %%
# loading dataset 
df = pd.read_csv("Dataset/Telco-Customer-Churn.csv")

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print(df.shape)
# Out:
# (7021, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df = df.drop("customerID", axis=1) #removing customer id because it's not imp for predictions

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   str
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   str
#  3   Dependents        7043 non-null   str
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   str
#  6   MultipleLines     7043 non-null   str
#  7   InternetService   7043 non-null   str
#  8   OnlineSecurity    7043 non-null   str
#  9   OnlineBackup      7043 non-null   str
#  10  DeviceProtection  7043 non-null   str
#  11  TechSupport       7043 non-null   str
#  12  StreamingTV       7043 non-null   str
#  13  StreamingMovies   7043 non-null   str
#  14  Contract          7043 non-null   str
#  15  PaperlessBilling  7043 non-null   str
#  16  PaymentMethod     7043 non-null   str
# ...

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce") #converting TotalCharges column to numeric
print(df["TotalCharges"].dtypes)
# Out:
# float64

# %%
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df["TotalCharges"] = df["TotalCharges"].fillna(df["TotalCharges"].median())

# %%
df.isnull().sum() #for checking if TotalCharges has null after handling
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(22)

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#EDA

# %%
plt.figure(figsize=(4,4))
sns.countplot(x="Churn", data=df)
plt.title("count of customers by Churn")
plt.show()
# churned vs non churned customers

# %%
churn_counts = df["Churn"].value_counts()
plt.figure(figsize=(4,4))
# pie chart of churn percentage
plt.pie(churn_counts, labels=churn_counts.index, autopct="%1.2f%%")
plt.title("Percentage of Churned Customers")

plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x="gender", hue="Churn", data=df) # comparing churn based on gender
plt.title("Churn by gender")
plt.show()

# %%
# comparing churn for senior citizens
plt.figure(figsize=(4,4))
sns.countplot(x="SeniorCitizen", hue="Churn", data=df)
plt.title("Churn by senior citizen")
plt.show()

# %%
# churn comparison for different contract types
plt.figure(figsize=(6,4))
sns.countplot(x="Contract", hue="Churn", data=df)
plt.title("Churn by contract Type")
plt.show()

# %%
cols = df.select_dtypes(include=["object", "string"]).columns #selecting category cols 

le = LabelEncoder()
#using loop for converting into binary number form 
for col in cols:
    df[col] = le.fit_transform(df[col])

# %%
df.select_dtypes(include=["object", "string"]).columns #verified that column has coverted
# Out:
# Index([], dtype='str')

# %%
# correlation heatmap to understand relationship between features
plt.figure(figsize=(10,8))
corr = df.corr()
sns.heatmap(corr, annot=False, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Observed Churn patterns

# %% [raw]
# 1.Overall Churn Count
# The number of customers who did not churn is higher compared to churned customers but still a good number of customers have left the service which shows churn is an important issue.
# 2.Churn Percentage
# From the pie chart it is seen that around one fourth of the customers have churned while most customers are still retained
# 3.Gender
# Churn rate looks almost similar for both male and female customers so gender does not have much impact on churn.
# 4.Senior Citizen
# Senior citizens show slightly higher churn compared to non senior customers which means age group may affect churn to some extent.
# 5.Contract Type
# Customers having month to month contracts show much higher churn compared to customers with one year or two year contracts so long term contracts help in customer retention.
# 6.Correlation Heatmap
# From the correlation heatmap no very strong relationship is seen between most features but some columns show moderate correlation which can help during model prediction.

# %%
#Model building and evaluation

# %%
# separating input features and target 
input_features = df.drop("Churn", axis=1)
target = df["Churn"]

# %%
# scaling input feature values
scaler = StandardScaler()
scaled_features = scaler.fit_transform(input_features)

# %%
#splitting data into training and testing parts 80:20 
train_input, test_input, train_output, test_output = train_test_split(scaled_features, target, test_size=0.2)

# %%
# logistic regression model
model = LogisticRegression()
model.fit(train_input, train_output) #training the model here
# Out:
# LogisticRegression()

# %%
# making predictions on test data
predictions = model.predict(test_input)

# %%
# checking accuracy and recall 
accuracy = accuracy_score(test_output, predictions)
recall = recall_score(test_output, predictions)
print("Accuracy-", accuracy)
print("Recall-", recall)
# Out:
# Accuracy- 0.8185053380782918
# Recall- 0.5864022662889519

# %%
print(classification_report(test_output, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88      1052
#            1       0.66      0.59      0.62       353
#
#     accuracy                           0.82      1405
#    macro avg       0.76      0.74      0.75      1405
# weighted avg       0.81      0.82      0.82      1405

# %%
# creating random forest model
rf_model = RandomForestClassifier()

# %%
# training random forest model
rf_model.fit(train_input, train_output)
# Out:
# RandomForestClassifier()

# %%
# making predictions using random forest
rf_predictions = rf_model.predict(test_input)

# %%
rf_accuracy = accuracy_score(test_output, rf_predictions)
rf_recall = recall_score(test_output, rf_predictions)

print("Random forest accuracy:", rf_accuracy)
print("Random forest recall:", rf_recall)
# Out:
# Random forest accuracy: 0.802846975088968
# Random forest recall: 0.5014164305949008

# %%
# comparining both the Models Regress Logistics vs Random forest

# %%
models = ["Logistic Regression", "Random Forest"]
accuracy_values = [accuracy, rf_accuracy]

# storing recall values
recall_values = [recall, rf_recall]

# creating dataframe for comparison
comparison = pd.DataFrame({
    "Model": models,
    "Accuracy": accuracy_values,
    "Recall": recall_values
})

print(comparison)
# Out:
#                  Model  Accuracy    Recall
# 0  Logistic Regression  0.818505  0.586402
# 1        Random Forest  0.802847  0.501416

# %% [markdown]
# Logistic Regression:
# Correctly predicted  81% overall
# Caught 59% of actual churn customers
#
# Random Forest:
# Correctly predicted 80% overall
# Caught 50% of actual churn customers

# %%
#Conclusion

# %% [raw]
# --In this project customer churn prediction was performed using Logistic Regression and Random Forest models. The dataset was first cleaned and analyzed using EDA to understand churn patterns. After preprocessing and splitting the data into training and testing sets both models were trained and evaluated using accuracy and recall.
#
# --Logistic Regression achieved an accuracy of around 81% and a recall of 58%, while Random Forest achieved an accuracy of 80% and a recall of 50%. Based on these results Logistic Regression performed slightly better than Random Forest for this dataset.
#
# --Overall this project helped in understanding the end to end machine learning process including data cleaning EDA model building and performance evaluation.
